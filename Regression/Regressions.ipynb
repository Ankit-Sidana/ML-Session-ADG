# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# #Importing Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/Session/archive (5)/kc_house_data.csv')
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df1 = df.copy()

# %%
df1 = df1.drop(['id','date'],axis=1)

# %%
df1.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
x = df1.iloc[:,1:].values
y = df1.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train
# Out:
# array([[ 1.00000e+00,  1.00000e+00,  9.60000e+02, ..., -1.21864e+02,
#          1.32000e+03,  2.03500e+04],
#        [ 3.00000e+00,  1.75000e+00,  1.51000e+03, ..., -1.22258e+02,
#          1.52000e+03,  1.00370e+04],
#        [ 3.00000e+00,  2.25000e+00,  1.67000e+03, ..., -1.22386e+02,
#          2.13000e+03,  7.03500e+03],
#        ...,
#        [ 3.00000e+00,  2.25000e+00,  2.36000e+03, ..., -1.22158e+02,
#          2.72000e+03,  1.43880e+04],
#        [ 4.00000e+00,  2.00000e+00,  2.37000e+03, ..., -1.22279e+02,
#          2.11000e+03,  1.93340e+04],
#        [ 4.00000e+00,  2.25000e+00,  2.38000e+03, ..., -1.22120e+02,
#          2.23000e+03,  8.92500e+03]])

# %%
x_test
# Out:
# array([[ 2.00000e+00,  1.50000e+00,  1.43000e+03, ..., -1.22290e+02,
#          1.43000e+03,  1.65000e+03],
#        [ 4.00000e+00,  3.25000e+00,  4.67000e+03, ..., -1.22164e+02,
#          4.23000e+03,  4.10750e+04],
#        [ 2.00000e+00,  7.50000e-01,  1.44000e+03, ..., -1.22364e+02,
#          1.44000e+03,  4.30000e+03],
#        ...,
#        [ 4.00000e+00,  2.50000e+00,  3.41000e+03, ..., -1.21986e+02,
#          3.35000e+03,  1.75421e+05],
#        [ 3.00000e+00,  1.50000e+00,  1.18000e+03, ..., -1.22032e+02,
#          1.28000e+03,  1.13710e+04],
#        [ 3.00000e+00,  1.00000e+00,  1.62000e+03, ..., -1.22347e+02,
#          1.42000e+03,  3.06000e+03]])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
x_train.shape
# Out:
# (16209, 18)

# %%
y_train.shape
# Out:
# (16209,)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
#score
from sklearn.metrics import r2_score


lr  = LinearRegression()
dt  = DecisionTreeRegressor(max_depth = 3)
rf  = RandomForestRegressor(max_depth = 3, n_estimators=500)
ada = AdaBoostRegressor( n_estimators=50, learning_rate =.01)
gbr = GradientBoostingRegressor(max_depth=2, n_estimators=100, learning_rate =.2)
xgb = XGBRegressor(max_depth = 3, n_estimators=50, learning_rate =.2)

regressors = [('Linear Regression', lr),('Decision Tree', dt), ('Random Forest', rf), 
              ('AdaBoost', ada),('Gradient Boosting Regressor', gbr),('XGBRegressor', xgb)]

# %%
for regressor_name, regressor in regressors:

    regressor.fit(x_train, y_train)    
  
    y_pred = regressor.predict(x_test)
    accuracy = round(r2_score(y_test,y_pred),3)*100
    
    print('{:s} : {:.0f} %'.format(regressor_name, accuracy))
    plt.rcParams["figure.figsize"] = (20,8)
    plt.bar(regressor_name,accuracy)
# Out:
# Linear Regression : 69 %
# Decision Tree : 59 %
# Random Forest : 67 %
# AdaBoost : 64 %
# Gradient Boosting Regressor : 86 %
# [08:05:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor : 87 %

# %%
rmse_scores = {}

# %% [markdown]
# ##Linear Regression:
# ![image.png](data:image/png;base64,...)

# %%
lr.predict(sc.transform([[2, 1.00,	770,	10000,	1.0,	0,	0,	3,	6,	770,	0,	1933,	0,	98028,	47.7379,	-122.233,	2720,	8062]]))
# Out:
# array([387835.16295571])

# %%
y_pred1 = lr.predict(x_test)
sns.regplot(x=y_test,y=y_pred1,ci=None,color ='red');

# %%
import math
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(y_test,y_pred1))
print(rmse)
# Out:
# 202899.48063177385

# %%
rmse_scores['Linear Regression'] = rmse

# %% [markdown]
# ##Decision Tree Regression
# ![image.png](data:image/png;base64,...)

# %%
dt.predict(sc.transform([[2, 1.00,	770,	10000,	1.0,	0,	0,	3,	6,	770,	0,	1933,	0,	98028,	47.7379,	-122.233,	2720,	8062]]))
y_pred2 = dt.predict(x_test)

# %%
rmse = math.sqrt(mean_squared_error(y_test,y_pred2))
print(rmse)
# Out:
# 233837.52610548804

# %%
rmse_scores['Decision Trees'] = rmse

# %%
from sklearn import tree
text_representation = tree.export_text(dt)
print(text_representation)
# Out:
# |--- feature_8 <= 0.71
# |   |--- feature_14 <= -0.19
# |   |   |--- feature_2 <= -0.16
# |   |   |   |--- value: [267878.45]
# |   |   |--- feature_2 >  -0.16
# |   |   |   |--- value: [391461.22]
# |   |--- feature_14 >  -0.19
# |   |   |--- feature_2 <= -0.05
# |   |   |   |--- value: [463377.56]
# |   |   |--- feature_2 >  -0.05
# |   |   |   |--- value: [654757.00]
# |--- feature_8 >  0.71
# |   |--- feature_2 <= 2.14
# |   |   |--- feature_14 <= -0.27
# |   |   |   |--- value: [554489.65]
# |   |   |--- feature_14 >  -0.27
# |   |   |   |--- value: [912452.76]
# |   |--- feature_2 >  2.14
# |   |   |--- feature_15 <= 0.10
# |   |   |   |--- value: [2088169.03]
# |   |   |--- feature_15 >  0.10
# |   |   |   |--- value: [1278037.23]

# %% [markdown]
# ##Random Forest Regressor
# ![image.png](data:image/png;base64,...)

# %%
rf.predict(sc.transform([[2, 1.00,	770,	10000,	1.0,	0,	0,	3,	6,	770,	0,	1933,	0,	98028,	47.7379,	-122.233,	2720,	8062]]))
y_pred3 = rf.predict(x_test)

# %%
rmse = math.sqrt(mean_squared_error(y_test,y_pred3))
print(rmse)
# Out:
# 210730.72732899906

# %%
rmse_scores['Random Forest Regressor'] = rmse

# %% [markdown]
# ##GradientBoost Regression

# %%
gbr.predict(sc.transform([[2, 1.00,	770,	10000,	1.0,	0,	0,	3,	6,	770,	0,	1933,	0,	98028,	47.7379,	-122.233,	2720,	8062]]))
y_pred4 = gbr.predict(x_test)

# %%
rmse = math.sqrt(mean_squared_error(y_test,y_pred4))
print(rmse)
# Out:
# 138290.04195325382

# %%
rmse_scores['Gradient Boost Regressor'] = rmse

# %% [markdown]
# ##ADAboost

# %%
ada.predict(sc.transform([[2, 1.00,	770,	10000,	1.0,	0,	0,	3,	6,	770,	0,	1933,	0,	98028,	47.7379,	-122.233,	2720,	8062]]))
y_pred5 = ada.predict(x_test)

# %%
rmse = math.sqrt(mean_squared_error(y_test,y_pred4))
print(rmse)
# Out:
# 138290.04195325382

# %%
rmse_scores['ADABoost'] = rmse

# %% [markdown]
# ##XGBoost

# %%
xgb.predict(sc.transform([[2, 1.00,	770,	10000,	1.0,	0,	0,	3,	6,	770,	0,	1933,	0,	98028,	47.7379,	-122.233,	2720,	8062]]))
y_pred6 = xgb.predict(x_test)

# %%
rmse = math.sqrt(mean_squared_error(y_test,y_pred6))
print(rmse)
# Out:
# 132778.07000089757

# %%
rmse_scores['XGBoost'] = rmse

# %% [markdown]
# #Comparing predicted values and the test values for each kind of regressor

# %%
 dk1 = pd.DataFrame({'Y_test':y_test,'Y_predict':lr.predict(x_test),'Difference':y_test-lr.predict(x_test)})
 dk1
# Out:
#          Y_test     Y_predict     Difference
# 0      297000.0  3.845722e+05  -87572.188558
# 1     1578000.0  1.528990e+06   49010.186530
# 2      562100.0  5.436045e+05   18495.486329
# 3      631500.0  5.789153e+05   52584.669580
# 4      780000.0  9.700640e+05 -190064.017776
# ...         ...           ...            ...
# 5399   649990.0  6.654050e+05  -15415.001546
# 5400   390000.0  3.319507e+05   58049.272258
# 5401   774950.0  7.563818e+05   18568.176130
# 5402   372500.0  2.351381e+05  137361.931061
# 5403   599995.0  5.906593e+05    9335.661913
#
# [5404 rows x 3 columns]

# %%
dk1.describe()
# Out:
#              Y_test     Y_predict    Difference
# count  5.404000e+03  5.404000e+03  5.404000e+03
# mean   5.350988e+05  5.367622e+05 -1.663371e+03
# std    3.645068e+05  3.008615e+05  2.029114e+05
# min    8.200000e+04 -2.327451e+05 -1.033888e+06
# 25%    3.193750e+05  3.343844e+05 -1.003818e+05
# 50%    4.445000e+05  4.848368e+05 -1.149647e+04
# 75%    6.370000e+05  6.851518e+05  7.223557e+04
# max    6.885000e+06  2.757851e+06  4.127149e+06

# %%
 dk2 = pd.DataFrame({'Y_test':y_test,'Y_predict':dt.predict(x_test),'Difference':y_test-dt.predict(x_test)})
 dk2
# Out:
#          Y_test     Y_predict     Difference
# 0      297000.0  4.633776e+05 -166377.563566
# 1     1578000.0  1.278037e+06  299962.767742
# 2      562100.0  4.633776e+05   98722.436434
# 3      631500.0  4.633776e+05  168122.436434
# 4      780000.0  9.124528e+05 -132452.763592
# ...         ...           ...            ...
# 5399   649990.0  9.124528e+05 -262462.763592
# 5400   390000.0  4.633776e+05  -73377.563566
# 5401   774950.0  5.544896e+05  220460.354892
# 5402   372500.0  4.633776e+05  -90877.563566
# 5403   599995.0  4.633776e+05  136617.436434
#
# [5404 rows x 3 columns]

# %%
dk2.describe()
# Out:
#              Y_test     Y_predict    Difference
# count  5.404000e+03  5.404000e+03  5.404000e+03
# mean   5.350988e+05  5.339824e+05  1.116368e+03
# std    3.645068e+05  2.755095e+05  2.338565e+05
# min    8.200000e+04  2.678785e+05 -1.646169e+06
# 25%    3.193750e+05  3.914612e+05 -1.007871e+05
# 50%    4.445000e+05  4.633776e+05 -2.414016e+04
# 75%    6.370000e+05  6.547570e+05  6.162244e+04
# max    6.885000e+06  2.088169e+06  4.796831e+06

# %%
dk3 = pd.DataFrame({'Y_test':y_test,'Y_predict':rf.predict(x_test),'Difference':y_test-rf.predict(x_test)})
dk3
# Out:
#          Y_test     Y_predict     Difference
# 0      297000.0  4.727936e+05 -175793.643726
# 1     1578000.0  1.482011e+06   95989.204407
# 2      562100.0  4.727936e+05   89306.356274
# 3      631500.0  4.732174e+05  158282.620507
# 4      780000.0  8.507347e+05  -70734.671020
# ...         ...           ...            ...
# 5399   649990.0  6.894753e+05  -39485.260322
# 5400   390000.0  4.732174e+05  -83217.379493
# 5401   774950.0  6.490330e+05  125916.963114
# 5402   372500.0  4.727936e+05 -100293.643726
# 5403   599995.0  4.727936e+05  127201.356274
#
# [5404 rows x 3 columns]

# %%
dk3.describe()
# Out:
#              Y_test     Y_predict    Difference
# count  5.404000e+03  5.404000e+03  5.404000e+03
# mean   5.350988e+05  5.348619e+05  2.369229e+02
# std    3.645068e+05  2.598085e+05  2.107501e+05
# min    8.200000e+04  2.782680e+05 -1.070812e+06
# 25%    3.193750e+05  3.316116e+05 -9.779364e+04
# 50%    4.445000e+05  4.727936e+05 -3.076800e+04
# 75%    6.370000e+05  6.773940e+05  5.220636e+04
# max    6.885000e+06  3.757827e+06  3.127173e+06

# %%
dk4 = pd.DataFrame({'Y_test':y_test,'Y_predict':gbr.predict(x_test), 'Difference':y_test-gbr.predict(x_test)})
dk4
# Out:
#          Y_test     Y_predict     Difference
# 0      297000.0  3.064333e+05   -9433.335378
# 1     1578000.0  1.628895e+06  -50894.874392
# 2      562100.0  5.281726e+05   33927.366125
# 3      631500.0  5.738867e+05   57613.271832
# 4      780000.0  7.775692e+05    2430.761687
# ...         ...           ...            ...
# 5399   649990.0  7.246450e+05  -74654.966691
# 5400   390000.0  5.123399e+05 -122339.858625
# 5401   774950.0  6.421296e+05  132820.416213
# 5402   372500.0  4.592283e+05  -86728.319734
# 5403   599995.0  5.869722e+05   13022.768468
#
# [5404 rows x 3 columns]

# %%
dk4.describe()
# Out:
#              Y_test     Y_predict    Difference
# count  5.404000e+03  5.404000e+03  5.404000e+03
# mean   5.350988e+05  5.333425e+05  1.756343e+03
# std    3.645068e+05  3.184835e+05  1.382917e+05
# min    8.200000e+04  1.251240e+05 -9.468897e+05
# 25%    3.193750e+05  3.240157e+05 -5.676459e+04
# 50%    4.445000e+05  4.647732e+05 -3.132873e+03
# 75%    6.370000e+05  6.459131e+05  4.625274e+04
# max    6.885000e+06  5.128794e+06  1.953572e+06

# %%
dk5 = pd.DataFrame({'Y_test':y_test,'Y_predict':xgb.predict(x_test),'Difference':y_test-xgb.predict(x_test)})
dk5
# Out:
#          Y_test     Y_predict    Difference
# 0      297000.0  3.252157e+05  -28215.65625
# 1     1578000.0  1.556493e+06   21506.75000
# 2      562100.0  5.264766e+05   35623.43750
# 3      631500.0  6.188218e+05   12678.25000
# 4      780000.0  7.656221e+05   14377.93750
# ...         ...           ...           ...
# 5399   649990.0  6.673441e+05  -17354.06250
# 5400   390000.0  4.663119e+05  -76311.90625
# 5401   774950.0  6.331962e+05  141753.75000
# 5402   372500.0  4.484987e+05  -75998.65625
# 5403   599995.0  5.591074e+05   40887.56250
#
# [5404 rows x 3 columns]

# %%
dk5.describe()
# Out:
#              Y_test     Y_predict    Difference
# count  5.404000e+03  5.404000e+03  5.404000e+03
# mean   5.350988e+05  5.330433e+05  2.055266e+03
# std    3.645068e+05  3.193384e+05  1.327744e+05
# min    8.200000e+04  1.499009e+05 -1.131325e+06
# 25%    3.193750e+05  3.241061e+05 -5.170199e+04
# 50%    4.445000e+05  4.601025e+05 -3.939953e+03
# 75%    6.370000e+05  6.402518e+05  4.174505e+04
# max    6.885000e+06  5.400234e+06  1.823732e+06

# %%
rmse_scores
# Out:
# {'ADABoost': 138290.04195325382,
#  'Decision Trees': 233837.52610548804,
#  'Gradient Boost Regressor': 138290.04195325382,
#  'Linear Regression': 202899.48063177385,
#  'Random Forest Regressor': 210730.72732899906,
#  'XGBoost': 132778.07000089757}
